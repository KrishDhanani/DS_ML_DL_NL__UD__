# %% [markdown]
# ### Custom exception (Raise and Throw an exception)

# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("Enter the date of birth..."))
age = 2024 - year

try:
    if age >= 20 and age <= 30:
        print("The age is valid so you can apply for exam")
    else:
        raise dobException
except dobException:
    print("Sorry, your age is not lie under crieteria.")
# Out:
# Enter the date of birth... 2003
# The age is valid so you can apply for exam
