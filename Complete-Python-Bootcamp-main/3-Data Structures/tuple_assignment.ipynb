# %% [markdown]
# # Module 3: Data Structures Assignments
# ## Lesson 3.2: Tuples
# ### Assignment 1: Creating and Accessing Tuples
#
# Create a tuple with the first 10 positive integers. Print the tuple.
#
# ### Assignment 2: Accessing Tuple Elements
#
# Print the first, middle, and last elements of the tuple created in Assignment 1.
#
# ### Assignment 3: Tuple Slicing
#
# Print the first three elements, the last three elements, and the elements from index 2 to 5 of the tuple created in Assignment 1.
#
# ### Assignment 4: Nested Tuples
#
# Create a nested tuple representing a 3x3 matrix and print the matrix. Access and print the element at the second row and third column.
#
# ### Assignment 5: Tuple Concatenation
#
# Concatenate two tuples: (1, 2, 3) and (4, 5, 6). Print the resulting tuple.
#
# ### Assignment 6: Tuple Methods
#
# Create a tuple with duplicate elements and count the occurrences of an element. Find the index of the first occurrence of an element in the tuple.
#
# ### Assignment 7: Unpacking Tuples
#
# Create a tuple with 5 elements and unpack it into 5 variables. Print the variables.
#
# ### Assignment 8: Tuple Conversion
#
# Convert a list of the first 5 positive integers to a tuple. Print the tuple.
#
# ### Assignment 9: Tuple of Tuples
#
# Create a tuple containing 3 tuples, each with 3 elements. Print the tuple of tuples.
#
# ### Assignment 10: Tuple and List
#
# Create a tuple with the first 5 positive integers. Convert it to a list, append the number 6, and convert it back to a tuple. Print the resulting tuple.
#
# ### Assignment 11: Tuple and String
#
# Create a tuple with the characters of a string. Join the tuple elements into a single string. Print the string.
#
# ### Assignment 12: Tuple and Dictionary
#
# Create a dictionary with tuple keys and integer values. Print the dictionary.
#
# ### Assignment 13: Nested Tuple Iteration
#
# Create a nested tuple and iterate over the elements, printing each element.
#
# ### Assignment 14: Tuple and Set
#
# Create a tuple with duplicate elements. Convert it to a set to remove duplicates and print the resulting set.
#
# ### Assignment 15: Tuple Functions
#
# Write functions that take a tuple and return the minimum, maximum, and sum of the elements. Print the results for a sample tuple.

# %%
# Assignment 1

import random

t = list(tuple())
for i in range(10):
    num = random.randint(1,10)
    t.append(num)

print(tuple(t))
# Out:
# (2, 1, 3, 8, 6, 8, 2, 4, 3, 5)

# %%
# Assignment 2

print(f"First element of tuple {t[0]}")
print(f"Middle element of tuple {t[5]}")
print(f"last element of tuple {t[-1]}")
# Out:
# First element of tuple 2
# Middle element of tuple 8
# last element of tuple 5

# %%
# Assignment 3

print(f"First three element of tuple {tuple(t[:3])}")
print(f"last three element of tuple {tuple(t[7:])}")
print(f"First three element of tuple {tuple(t[2:5:1])}")
# Out:
# First three element of tuple (2, 1, 3)
# last three element of tuple (4, 3, 5)
# First three element of tuple (3, 8, 6)

# %%
# Assignment 4

matrix = (
    (1, 2, 3),
    (4, 5, 6),
    (7, 8, 9)
)

print(f"Second row and third column element {matrix[1][2]}")
# Out:
# Second row and third column element 6

# %%
# Assignment 5

t1 = (1,2,3)
t2 = (4,5,6)

print(t1 + t2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# Assignment 6

t = (1,2,2,2,3,4,5,5)
print(f"In our tuple 2 occur {t.count(2)} times.")
print(f"First occurence of 2 in our tuple is {t.index(2)}")
# Out:
# In our tuple 2 occur 3 times.
# First occurence of 2 in our tuple is 1

# %%
# Assignment 7
t = (1,2,3,4,5)
a1,a2,a3,a4,a5 = t 
print(a1)
# Out:
# 1

# %%
# Assignment 8

lst = [1,2,3,4,5]
t = tuple(lst)
print(t)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Assignment 9
t = (
    (1,2,3),
    (4,5,6),
    (7,8,9)
    )
print(t)
# Out:
# ((1, 2, 3), (4, 5, 6), (7, 8, 9))

# %%
# Assignment 10

t = (1,2,3,4,5)
l = list(t)

l.append(6)
t = tuple(l)
print(t)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
# Assignment 11

t = ('k', 'r', 'i', 's', 'h')
str = ""
# OR ''.join(tpl)
for i in t:
    str += i
print(str)
# Out:
# krish

# %%
# Assignment 12

tup = {
    (1,2): 3,
    (4,5): 7
}
print(tup)
# Out:
# {(1, 2): 3, (4, 5): 7}

# %%
# Assignment 13

tup = (
    (1,2,3),
    (2,3,4),
    (3,4,5)
)
for i in tup:
    for j in i:
        print(j, end=' ')
# Out:
# 1 2 3 2 3 4 3 4 5

# %%
# Assignment 14

t = (1,2,3,4,4,4,5)

s = set(t)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
# Assignment 15

def min_in_tuple(tpl):
    return min(tpl)

def max_in_tuple(tpl):
    return max(tpl)

def sum_of_tuple(tpl):
    return sum(tpl)

sample_tpl = (1, 2, 3, 4, 5)
print(f"Minimum: {min_in_tuple(sample_tpl)}")
print(f"Maximum: {max_in_tuple(sample_tpl)}")
print(f"Sum: {sum_of_tuple(sample_tpl)}")
# Out:
# Minimum: 1
# Maximum: 5
# Sum: 15
